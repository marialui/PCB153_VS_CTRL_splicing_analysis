# %% [markdown]
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mkdir CTR-1 CTR-2 PCB118-1  PCB118-2  PCB153-1  PCB153-2
#
# (base) maria@maria-VirtualBox:~/Desktop$ scp maria@bioinformatics:/home/maria/sharing/bam_inquinanti/*FinalAligned.sortedByCoord.out.bam /home/maria/Desktop/inquinanti_splicing
#
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mv CTRL-WT-1* CTR-1
#
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mv CTRL-WT-2* CTR-2
#
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mv PCB118-5uM-1* PCB118-1
#
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mv PCB118-5uM-2* PCB118-2
#
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mv PCB153-5uM-1* PCB153-1
#
# (base) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ mv PCB153-5uM-2* PCB153-2

# %% [markdown]
# for d in CTR-1 CTR-2 PCB118-1 PCB118-2 PCB153-1 PCB153-2; do mv "$d"/*.bam "$d/FinalAligned.sortedByCoord.out.bam"; done

# %% [markdown]
# conda activate rmats-env

# %%
# !ls
# Out:
# 0_rmats.ipynb			     CTR-Tau_bams.txt	  PCB153-1
# 1_rmats.ipynb			     Figure1.ipynb	  PCB153-2
# 2_rmats.ipynb			     Figure2.ipynb	  PCB153_bams.txt
# A3SS				     GTF_GRCh38		  PCB153-Tau-1
# A5SS				     merged_DASE	  PCB153-Tau-2
# ASE_count_per_class_with_values.png  MXE		  PCB153-Tau_bams.txt
# codes				     PCB118-1		  RI
# CTR-1				     PCB118-2		  rMATS_PCB118-vs-CTR
# CTR-2				     PCB118_bams.txt	  rMATS_PCB153-vs-CTR
# CTR_bams.txt			     PCB118-Tau-1	  SE
# CTR-Tau-1			     PCB118-Tau-2	  tmp_output1
# CTR-Tau-2			     PCB118-Tau_bams.txt  tmp_output2

# %% [markdown]
# (rmats-env) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ rmats.py --b1 PCB153_bams.txt --b2 CTR_bams.txt --gtf /home/maria/Desktop/inquinanti_splicing/GTF_GRCh38/Homo_sapiens.GRCh38.112.gtf -t paired --nthread 4 --readLength 75 --od rMATS_PCB153-vs-CTR --tmp tmp_output1 --anchorLength 2 --novelSS

# %% [markdown]
# (rmats-env) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ rmats.py --b1 PCB118_bams.txt --b2 CTR_bams.txt --gtf /home/maria/Desktop/inquinanti_splicing/GTF_GRCh38/Homo_sapiens.GRCh38.112.gtf -t paired --nthread 4 --readLength 75 --od rMATS_PCB118-vs-CTR --tmp tmp_output2 --anchorLength 2 --novelSS

# %% [markdown]
# (rmats-env) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ rmats.py --b1 CTR-Tau_bams.txt --b2 CTR_bams.txt --gtf /home/maria/Desktop/inquinanti_splicing/GTF_GRCh38/Homo_sapiens.GRCh38.112.gtf -t paired --nthread 4 --readLength 75 --od rMATS_CTR-Tau-vs-CTR --tmp tmp_output3 --anchorLength 2 --novelSS

# %% [markdown]
# (rmats-env) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ rmats.py --b1 PCB153-Tau_bams.txt --b2 CTR-Tau_bams.txt --gtf /home/maria/Desktop/inquinanti_splicing/GTF_GRCh38/Homo_sapiens.GRCh38.112.gtf -t paired --nthread 4 --readLength 75 --od rMATS_PCB153-Tau-vs-CTR-Tau --tmp tmp_output4 --anchorLength 2 --novelSS

# %% [markdown]
# (rmats-env) maria@maria-VirtualBox:~/home/maria/Desktop/inquinanti_splicing$ rmats.py --b1 PCB118-Tau_bams.txt --b2 CTR-Tau_bams.txt --gtf /home/maria/Desktop/inquinanti_splicing/GTF_GRCh38/Homo_sapiens.GRCh38.112.gtf -t paired --nthread 4 --readLength 75 --od rMATS_PCB118-Tau-vs-CTR-Tau --tmp tmp_output5 --anchorLength 2 --novelSS
